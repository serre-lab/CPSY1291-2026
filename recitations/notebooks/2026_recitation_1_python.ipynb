# %% [markdown]
# Based on a notebook written by [Justin Johnson](https://web.eecs.umich.edu/~justincj/).
#
# Based on Sept 2023, Alekh; Sept 2025, Sixuan; Sept 2026, Peisen

# %% [markdown]
# # **CPSY1291 Fall26**
# ## **Recitation 1**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# Python is a great general-purpose programming language on its own, but with the help of a few popular libraries (numpy, scipy, matplotlib) it becomes a powerful environment for scientific computing.
#
#
# If you have previous knowledge of Matlab, this "numpy for Matlab users" page might be helpful - https://numpy.org/doc/stable/user/numpy-for-matlab-users.html

# %% [markdown]
# In this tutorial, we will cover:
#
# * Basic Python: Basic data types (Containers, Lists, Dictionaries, Sets, Tuples), Functions, Classes

# %% [markdown]
# Python usually comes installed with Linux distros and Macs. In any case, updating or installing python is easy - https://python.land/installing-python. A popular way to install python and manage the libraries is conda - https://conda.io/projects/conda/en/latest/user-guide/install/index.html
#
# Generally, python code is saved in file with .py extension and the python program is used to run it (`python example.py`) For this course, we will use Colab, which hosts Jupyter notebooks. Python and the necessary libraries are already installed in Colab.
#
# As of Janurary 1, 2020, Python has [officially dropped support](https://www.python.org/doc/sunset-python-2/) for `python2`. We'll be using Python 3 for this course. You can check your Python version at the command line by running `python --version`. Colab only has Python 3.

# %%
# !python --version

# %%
print("hello world")

# %% [markdown]
# ## **Basics of Python**

# %% [markdown]
# Python is a high-level, dynamically typed multiparadigm programming language. Python code is often said to be almost like pseudocode, since it allows you to express very powerful ideas in very few lines of code while being very readable.

# %% [markdown]
# ### **Basic data types**

# %% [markdown]
# #### Numbers

# %% [markdown]
# Integers and floats work as you would expect from other languages:

# %%
x = 3
print(x, type(x))

# %% [markdown]
# Baisc numerical operations

# %%
print(x + 1)   # Addition
print(x - 1)   # Subtraction
print(x * 2)   # Multiplication
print(x / 2)   # Division

# %% [markdown]
# Advance numeric operations

# %%
print(x // 2)  # Integer Division
print(x % 2)   # Modulo
print(x ** 2)  # Exponentiation

# %% [markdown]
# Shortcut for updating a numerical variable

# %%
x += 1
print(x)
x *= 2
print(x)

# %% [markdown]
# Note that unlike many languages, Python does not have unary increment (x++) or decrement (x--) operators.

# %% [markdown]
# Floating point numbers

# %%
y = 2.5
print(type(y))
print(y, y + 1, y * 2, y ** 2)

# %% [markdown]
# Rounding

# %%
z = 1.23456789
z = round(z, 3) # rounding to 3 decimal places
print(z)

# %% [markdown]
# Equality

# %%
x = 1.2
y = 1.3
print(x == y) # Equality
print(x != y) # Inequality
print(x < y) # Less than
print(x <= y) # Less than or equal to

# %% [markdown]
# Python also has built-in types for long integers and complex numbers; you can find all of the details in the [documentation](https://docs.python.org/3.7/library/stdtypes.html#numeric-types-int-float-long-complex).

# %% [markdown]
# #### Booleans

# %% [markdown]
# Python implements all of the usual operators for Boolean logic, but uses English words rather than symbols (`&&`, `||`, etc.):

# %%
t = True
f = False
print(type(t))

# %% [markdown]
# Now we let's look at the operations:

# %%
print(t and f) # Logical AND;
print(t or f)  # Logical OR;
print(not t)   # Logical NOT;
print(t != f)  # Logical XOR;

# %% [markdown]
# #### Strings

# %%
hello = 'hello'   # String literals can use single quotes
world = "world"   # or double quotes; it does not matter
print(hello, len(hello))

# %%
hw = hello + '_' + world  # String concatenation
print(hw)

# %%
word_1 = "Hello"
format_string = f'{word_1} world!' # f-string formatting with variables
print(format_string)

# %% [markdown]
# You can find a list of all string methods in the [documentation](https://docs.python.org/3.7/library/stdtypes.html#string-methods).

# %% [markdown]
# ### **Control flow**

# %% [markdown]
# #### If statements
#
#
# ```
# if condition:
#    # Statements to execute if
#    # condition is true
# elif another condition:
#    # Statements to execute if
#    # another condition is true
# else:
#    # Statements to execute if
#    # both conditions are false
# ```

# %%
#chain conds
#nested if

i = 5
if i==5:
  print("i is 5")
elif i==6:
  print("i is 6")
else:
  print("i is not 5 or 6")

# %% [markdown]
# #### Loops
# For Loop

# %%
for i in range(10):
  print(i)

# %%
my_string = "CPSY1291"
for i in my_string:
  print(i)

# %% [markdown]
# While Loop

# %%
c = 23
while c < 27:
  print(c)
  c+=1

# %% [markdown]
# Break out of loop

# %%
c = 23
while True:
  print(c)
  c+=1
  if c>26:
    break

# %% [markdown]
# ### **Containers**

# %% [markdown]
# #### Lists

# %% [markdown]
# A list is the Python equivalent of an array. Note that it is resizeable and can contain elements of different types:

# %%
xs = [3, 1, 2]   # Create a list
print(xs)
print(xs[0])

# %%
xs[2] = 'foo'    # Lists can contain elements of different types
print(xs)

# %%
xs.append('bar') # Add a new element to the end of the list
print(xs)

# %%
xs = xs + ['28', 28]
print(xs)

# %%
xs = xs * 2
print(xs)

# %% [markdown]
# You can find all the details about lists in the [documentation](https://docs.python.org/3.7/tutorial/datastructures.html#more-on-lists).

# %% [markdown]
# #### Slicing

# %% [markdown]
# In addition to accessing list elements one at a time, Python provides concise syntax to access sublists; this is known as slicing:

# %%
nums = list(range(5))    # range is a built-in function that creates a list of integers
print(nums)         # Prints "[0, 1, 2, 3, 4]"
print(nums[2:5])    # Get a slice from index 2 to 4 (exclusive); prints "[2, 3]"
print(nums[2:])     # Get a slice from index 2 to the end; prints "[2, 3, 4]"
print(nums[:2])     # Get a slice from the start to index 2 (exclusive); prints "[0, 1]"
print(nums[:])      # Get a slice of the whole list; prints ["0, 1, 2, 3, 4]"
print(nums[:-1])    # Slice indices can be negative; prints ["0, 1, 2, 3]"
nums[2:4] = [8, 9]  # Assign a new sublist to a slice
print(nums)         # Prints "[0, 1, 8, 9, 4]"

# %% [markdown]
# #### Loops

# %% [markdown]
# You can loop over the elements of a list like this:

# %%
animals = ['cat', 'dog', 'monkey']

for i in range(len(animals)):
    print(animals[i])

for a in animals:
     print(a)

# %% [markdown]
# #### List comprehensions:

# %% [markdown]
# When programming, we often want to transform one type of data into another. As a simple example, consider the following code that computes square numbers:

# %%
nums = [0, 1, 2, 3, 4]
squares = []
for x in nums:
    squares.append(x ** 2)
print(squares)

# %% [markdown]
# You can make this code smaller using a list comprehension:

# %%
nums = [0, 1, 2, 3, 4]
squares = [x ** 2 for x in nums]
print(squares)

# %% [markdown]
# #### Dictionaries

# %% [markdown]
# A dictionary stores (key, value) pairs, similar to a `Map` in Java or an object in Javascript. You can use it like this:

# %%
d = {7: [1,2,3],
     'cat': 'cute',
     'dog': 'furry'}  # Create a new dictionary with some data
print(d['cat'])           # Get an entry from a dictionary; prints "cute"
print('cat' in d)     # Check if a dictionary has a given key; prints "True"

# %%
d['fish'] = 'wet'    # Set an entry in a dictionary
print(d['fish'])      # Prints "wet"

# %%
print(d['monkey'])  # KeyError: 'monkey' not a key of d

# %%
print(d.keys())

# %% [markdown]
# You can find all you need to know about dictionaries in the [documentation](https://docs.python.org/2/library/stdtypes.html#dict).

# %% [markdown]
# It is easy to iterate over the keys in a dictionary:

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}

for animal, legs in d.items():
    print(f'A {animal} has {legs} legs')

# %% [markdown]
# ### **Functions**

# %% [markdown]
# Functions are reusable blocks of logic. Python functions are defined using the `def` keyword. For example:

# %%
def sign(x):
    if x > 0:
        return 'positive'
    elif x < 0:
        return 'negative'
    return 0

def add (x,y):
    return x + y

# %%
print(add(2,3))

for x in [-1, 0, 1]:
    print(sign(x))

# %% [markdown]
# We will often define functions to take optional keyword arguments, like this:

# %%
def hello(name, loud=False):
    if loud:
        print(f'HELLO, {name.upper()}')
    else:
        print(f'Hello, {name}!')

hello('Bob')
hello('Fred', loud=True)

# %% [markdown]
# ### **Classes**

# %% [markdown]
# Classes allow us to create objects with similar functions, but with different properties. The syntax for defining classes in Python is straightforward:

# %%
# A simple class to greet people
class Greeter:

    # Constructor
    def __init__(self, name):
        self.name = name  # Create an instance variable

    # Instance method
    def greet(self, loud=False):
        if loud:
          print(f'HELLO, {self.name.upper()}')
        else:
          print(f'Hello, {self.name}!')

g = Greeter('Fred')  # Construct an instance of the Greeter class
g.greet()            # Call an instance method; prints "Hello, Fred"
g.greet(loud=True)   # Call an instance method; prints "HELLO, FRED!"
